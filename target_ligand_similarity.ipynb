# %%
import os
import pandas as pd
import torch
import pickle
import matplotlib.pyplot as plt
import seaborn as sns

from IPython.display import display
from tqdm import tqdm
from litschnet import LitSchNet
from conf_ensemble_dataset_in_memory import ConfEnsembleDataset
from rmsd_predictor_evaluator import RMSDPredictorEvaluator
from pdbbind_metadata_processor import PDBBindMetadataProcessor
from chembl_connector import ChEMBLConnector
from torch.utils.data import ConcatDataset
from rdkit import Chem
from rdkit.Chem import Draw
from rdkit.Chem.Scaffolds.MurckoScaffold import MurckoScaffoldSmiles, MakeScaffoldGeneric, GetScaffoldForMol

# %%
import numpy as np
from rdkit import Chem
from rdkit.Chem import AllChem
from rdkit import DataStructs
from rdkit.DataManip.Metric.rdMetricMatrixCalc import GetTanimotoSimMat
from rdkit.DataStructs.cDataStructs import BulkTanimotoSimilarity
class SimilaritySearch() :
    
    def __init__(self, smiles_list) :
        self.smiles_list = list(set(smiles_list))
        self.mols = [Chem.MolFromSmiles(smiles) for smiles in self.smiles_list]
        self.fps = [self.get_morgan_fingerprint(mol) for mol in self.mols]
        self.sim_matrix = self.get_sim_matrix()
        print('Similarity matrix ready')
        
    def get_sim_matrix(self) :
#         sim_triangle = GetTanimotoSimMat(self.fps)
#         sim_matrix = self.tri2mat(sim_triangle)
#         return sim_matrix
        
        n_fps = len(self.fps)
        sim_matrix = np.eye(n_fps)
        for i, fp1 in enumerate(self.fps) :
            fp1 = self.fps[i]
            other_fps = self.fps[i+1:]
            sims = BulkTanimotoSimilarity(fp1, other_fps)
            for j, sim in enumerate(sims) :
                sim_matrix[i, i + 1 + j] = sim_matrix[i + 1 + j, i] = sim
        return sim_matrix
        
    def get_morgan_fingerprint(self, mol) :
        return AllChem.GetMorganFingerprintAsBitVect(mol, 3, useChirality=True)
        
    def get_similarity(self, fp1, fp2) :
        return DataStructs.TanimotoSimilarity(fp1, fp2)
        
    def find_closest_in_set(self, smiles, n=1) :
        
        #import pdb; pdb.set_trace()
        
        if smiles in self.smiles_list :
            smiles_index = self.smiles_list.index(smiles)
            sims = self.sim_matrix[smiles_index]
            sims = [sim for i, sim in enumerate(sims) if i != smiles_index]
            smiles_list = [s for i, s in enumerate(self.smiles_list) if i != smiles_index]
        else :
            input_mol = Chem.MolFromSmiles(smiles)
            input_fp = self.get_morgan_fingerprint(input_mol)
            sims = [self.get_similarity(input_fp, fp2) for fp2 in self.fps]
            smiles_list = self.smiles_list
            
        sims = np.array(sims)
        best_sim_indexes = np.argsort(-sims)[:n] # negate to get best
        closest_smiles = [smiles_list[i] for i in best_sim_indexes]
        closest_sims = sims[best_sim_indexes]
        return closest_smiles, closest_sims
        
    def tri2mat(self, tri_arr):
        n = len(tri_arr)
        m = int((np.sqrt(1 + 4 * 2 * n) + 1) / 2)
        arr = np.ones([m, m])
        for i in range(m):
            for j in range(i):
                arr[i][j] = tri_arr[i + j - 1]
                arr[j][i] = tri_arr[i + j - 1]
        return arr
        
#     def find_closest_in_set(self, smiles, n=1) :
#         if smiles in self.smiles_list :
#             #print('smiles in set, returning next closests')
#             other_smiles_index = [i for i, s in enumerate(self.smiles_list) if s != smiles]
#             smiles_list = [s for i, s in enumerate(self.smiles_list) if i in other_smiles_index]
#             mols = [mol for i, mol in enumerate(self.mols) if i in other_smiles_index]
#             fps = [fp for i, fp in enumerate(self.fps) if i in other_smiles_index]
#         else :
#             smiles_list = self.smiles_list
#             mols = self.mols
#             fps = self.fps
            
#         input_mol = Chem.MolFromSmiles(smiles)
#         input_fp = self.get_morgan_fingerprint(input_mol)
#         sims = [self.get_similarity(input_fp, fp2) for fp2 in fps]
#         sims = np.array(sims)
#         best_sim_indexes = np.argsort(-sims)[:n] # negate to get best
#         closest_smiles = [smiles_list[i] for i in best_sim_indexes]
#         closest_sims = sims[best_sim_indexes]
#         return closest_smiles, closest_sims

# %%
pdbbind_table = PDBBindMetadataProcessor().get_master_dataframe(remove_peptide_ligands=False)
chembl_table = ChEMBLConnector().get_target_table(level=3)
merged_table = pdbbind_table.merge(chembl_table, left_on='Uniprot ID', right_on='accession')
smiles_df = pd.read_csv('data/smiles_df.csv')
included_smiles = smiles_df[smiles_df['included']]['smiles'].unique()
included_pdb_ids = smiles_df[smiles_df['included']]['id'].unique()

# %%
# %%time
ss = SimilaritySearch(smiles_list=included_smiles)
# Out:
# Similarity matrix ready
# CPU times: user 23.1 s, sys: 288 ms, total: 23.4 s
# Wall time: 23.4 s

# %%
merged_table[merged_table['gene_symbol_lowercase'] == 'brpf1']
# Out:
#      PDB code resolution release year_x  -logKd/Ki             Kd/Ki  \
# 4438     3mo8       1.69           2010       3.10  Kd=0.8mM      //
# 4439     3mo8       1.69           2010       3.10  Kd=0.8mM      //
# 4440     3mo8       1.69           2010       3.10  Kd=0.8mM      //
# 4441     5o4t       1.50           2018       3.40  IC50>400uM    //
# 4442     5o4t       1.50           2018       3.40  IC50>400uM    //
# ...       ...        ...            ...        ...               ...
# 4532     5myg       2.30           2017       7.51  Kd=31nM       //
# 4533     5myg       2.30           2017       7.51  Kd=31nM       //
# 4534     4uye       1.65           2014       8.02  Kd=9.54nM     //
# 4535     4uye       1.65           2014       8.02  Kd=9.54nM     //
# 4536     4uye       1.65           2014       8.02  Kd=9.54nM     //
#
#      reference ligand name  activity_list sep      value units  \
# 4438  3mo8.pdf    (12-mer)   [mM, =, 0.8]   =  800000.00    nM
# 4439  3mo8.pdf    (12-mer)   [mM, =, 0.8]   =  800000.00    nM
# 4440  3mo8.pdf    (12-mer)   [mM, =, 0.8]   =  800000.00    nM
# 4441  5mwg.pdf       (9KT)   [uM, >, 400]   >  400000.00    nM
# 4442  5mwg.pdf       (9KT)   [uM, >, 400]   >  400000.00    nM
# ...        ...         ...            ...  ..        ...   ...
# 4532  5myg.pdf       (LS8)    [nM, =, 31]   =      31.00    nM
# 4533  5myg.pdf       (LS8)    [nM, =, 31]   =      31.00    nM
# 4534  4uyd.pdf       (9F9)  [nM, =, 9.54]   =       9.54    nM
# 4535  4uyd.pdf       (9F9)  [nM, =, 9.54]   =       9.54    nM
# 4536  4uyd.pdf       (9F9)  [nM, =, 9.54]   =       9.54    nM
#
#       release year_y Uniprot ID protein name  active accession  \
# 4438            2010     P55201     PEREGRIN   False    P55201
# 4439            2010     P55201     PEREGRIN   False    P55201
# 4440            2010     P55201     PEREGRIN   False    P55201
# 4441            2018     P55201     PEREGRIN   False    P55201
# 4442            2018     P55201     PEREGRIN   False    P55201
# ...              ...        ...          ...     ...       ...
# 4532            2017     P55201     PEREGRIN    True    P55201
# 4533            2017     P55201     PEREGRIN    True    P55201
# 4534            2014     P55201     PEREGRIN    True    P55201
# 4535            2014     P55201     PEREGRIN    True    P55201
# 4536            2014     P55201     PEREGRIN    True    P55201
#
#      component_synonym                                 protein_class_desc  \
# 4438             BRPF1                  epigenetic regulator  reader  brd
# 4439             BRPF1                  epigenetic regulator  reader  phd
# 4440             BRPF1  epigenetic regulator  reader  methyl-lysine  pwwp
# 4441             BRPF1                  epigenetic regulator  reader  brd
# 4442             BRPF1                  epigenetic regulator  reader  phd
# ...                ...                                                ...
# 4532             BRPF1                  epigenetic regulator  reader  phd
# 4533             BRPF1  epigenetic regulator  reader  methyl-lysine  pwwp
# 4534             BRPF1                  epigenetic regulator  reader  brd
# 4535             BRPF1                  epigenetic regulator  reader  phd
# 4536             BRPF1  epigenetic regulator  reader  methyl-lysine  pwwp
#
#                                            level3 gene_symbol_lowercase
# 4438            epigenetic regulator  reader  brd                 brpf1
# 4439            epigenetic regulator  reader  phd                 brpf1
# 4440  epigenetic regulator  reader  methyl-lysine                 brpf1
# 4441            epigenetic regulator  reader  brd                 brpf1
# 4442            epigenetic regulator  reader  phd                 brpf1
# ...                                           ...                   ...
# 4532            epigenetic regulator  reader  phd                 brpf1
# 4533  epigenetic regulator  reader  methyl-lysine                 brpf1
# 4534            epigenetic regulator  reader  brd                 brpf1
# 4535            epigenetic regulator  reader  phd                 brpf1
# 4536  epigenetic regulator  reader  methyl-lysine                 brpf1
#
# [99 rows x 20 columns]

# %%
for gene_symbol in merged_table['gene_symbol_lowercase'].value_counts().index :
    print(gene_symbol)
    gene_table = merged_table[(merged_table['gene_symbol_lowercase'] == gene_symbol)
                          & (merged_table['PDB code'].isin(included_pdb_ids))]
    gene_pdbs = gene_table['PDB code'].unique()
    gene_smiles = smiles_df[(smiles_df['id'].isin(gene_pdbs)) 
                            & (smiles_df['included'])]['smiles'].unique()
    
    gene_in_closest = []
    for smiles in gene_smiles :
        mol = Chem.MolFromSmiles(smiles)
        #display(mol)
        closest_smiles, closest_sims = ss.find_closest_in_set(smiles)
        #display(Draw.MolsToGridImage([Chem.MolFromSmiles(smiles) for smiles in closest_smiles]))
        closest_pdbs = smiles_df[(smiles_df['smiles'].isin(closest_smiles)) 
                             & (smiles_df['included'])]['id'].unique()
        closest_pdbbind = merged_table[merged_table['PDB code'].isin(closest_pdbs)]
        genes = closest_pdbbind['gene_symbol_lowercase'].values
        gene_in_closest.append(gene_symbol in genes)
        
    print(np.mean(gene_in_closest))
# Out:
# ca2
# 0.8021978021978022
# bace1
# 0.9535603715170279
# gag-pol
# 0.6748466257668712
# cdk2
# 0.6666666666666666
# brd4
# 0.6684782608695652
# f2
# 0.7439024390243902
# hsp90aa1
# 0.7730061349693251
# mapk14
# 0.7
# jak2
# 0.5737704918032787
# kdm4a
# 0.7142857142857143
# tnks2
# 0.819047619047619
# pygm
# 0.7625
# brpf1
# 0.3548387096774194
# ephx2
# 0.3125
# prkaca
# 0.7352941176470589
# f10
# 0.8350515463917526
# aurka
# 0.5212765957446809
# ptpn1
# 0.8923076923076924
# chek1
# 0.6744186046511628
# bla
# 0.75
# plau
# 0.5483870967741935
# pim1
# 0.37209302325581395
# ache
# 0.7710843373493976
# dpp4
# 0.8170731707317073
# pde10a
# 0.6428571428571429
# crebbp
# 0.675
# egfr
# 0.7878787878787878
# src
# 0.4782608695652174
# ampc
# 0.5675675675675675
# mdm2
# 0.7924528301886793
# gria2
# 0.6981132075471698
# esr1
# 0.6530612244897959
# ren
# 0.859375
# jak3
# 0.696969696969697
# pparg
# 0.5172413793103449
# mapk1
# 0.6779661016949152
# wdr5
# 0.6190476190476191
# ttr
# 0.5932203389830508
# kdm5a
# 0.7857142857142857
# pik3cg
# 0.6290322580645161
# rorc
# 0.6949152542372882
# csnk2a1
# 0.6981132075471698
# met
# 0.7169811320754716
# folh1
# 0.9166666666666666
# pde4d
# 0.7659574468085106
# jak1
# 0.6538461538461539
# btk
# 0.6122448979591837
# baz2b
# 0.6666666666666666
# mmp12
# 0.7692307692307693
# syk
# 0.5217391304347826
# ttk
# 0.7
# f11
# 0.9333333333333333
# fdps
# 0.5882352941176471
# rnase1
# 0.75
# nr1h4
# 0.7727272727272727
# braf
# 0.6046511627906976
# mcl1
# 0.8648648648648649
# gsk3b
# 0.5227272727272727
# oxa-48
# 0.9318181818181818
# mapk10
# 0.6190476190476191
# f7
# 0.7674418604651163
# pdpk1
# 0.525
# tyk2
# 0.7619047619047619
# sfn
# 0.0
# lgals3
# 0.8378378378378378
# mmp13
# 0.6
# tgt
# 0.90625
# hdac8
# 0.4857142857142857
# lta4h
# 0.6470588235294118
# plk1
# 0.8461538461538461
# xiap
# 0.6451612903225806
# eapa
# 0.2857142857142857
# ctsk
# 0.7058823529411765
# elob
# 0.9411764705882353
# kif11
# 0.8823529411764706
# ar
# 0.7
# vdr
# 0.9354838709677419
# alk
# 0.7777777777777778
# npr
# 0.18181818181818182
# pde2a
# 0.8387096774193549
# abl1
# 0.3103448275862069
# irak4
# 0.6666666666666666
# tp53
# 0.84375
# nampt
# 0.625
# pnp
# 0.4117647058823529
# kdm1a
# 0.8461538461538461
# comt
# 0.7586206896551724
# chek2
# 0.5862068965517241
# epha2
# 0.76
# nudt1
# 0.3448275862068966
# pik3cd
# 0.5666666666666667
# parp1
# 0.5555555555555556
# itk
# 0.6551724137931034
# pde4b
# 0.6153846153846154
# kdr
# 0.4482758620689655
# baz2a
# 0.16666666666666666
# mif
# 0.4230769230769231
# eed
# 0.7142857142857143
# brd2
# 0.6666666666666666
# blavim-2
# 0.5652173913043478
# arg1
# 0.5833333333333334
# thya
# 0.5333333333333333
# pin1
# 0.7619047619047619
# casp3
# 0.46153846153846156
# grik1
# 0.65
# pnmt
# 0.5652173913043478
# pde5a
# 0.7727272727272727
# kat2b
# 0.4
# fnta
# 0.6818181818181818
# uhrf1
# 0.0
# ack2
# 0.5
# cpb1
# 0.6666666666666666
# mmp3
# 0.5454545454545454
# fabp4
# 0.68
# e
# 0.4117647058823529
# ace
# 0.4
# fgfr1
# 0.45454545454545453
# men1
# 0.9090909090909091
# rxra
# 0.5652173913043478
# bcl6
# 0.5238095238095238
# metap1
# 0.5384615384615384
# tnks
# 0.4090909090909091
# hsp82
# 0.65
# dyrk1a
# 0.6666666666666666
# bche
# 0.6190476190476191
# pla2g7
# 0.7391304347826086
# cfd
# 0.6521739130434783
# lck
# 0.2631578947368421
# atp2a1
# 0.5714285714285714
# trim24
# 0.5454545454545454
# rps6ka3
# 0.5714285714285714
# kras
# 0.6666666666666666
# ctsl
# 0.8666666666666667
# itgal
# 0.5454545454545454
# dnan
# 0.4117647058823529
# map
# 0.45
# folk
# 0.6470588235294118
# cdk8
# 0.8095238095238095
# ctss
# 0.45
# atad2
# 0.3333333333333333
# bcl2l1
# 0.6153846153846154
# map2k1
# 0.65
# pik3ca
# 0.2
# gopc
# 0.0
# coad
# 0.5789473684210527
# metap2
# 0.6
# fkbp5
# 0.8666666666666667
# csnk1d
# 0.5789473684210527
# mdm4
# 0.3
# brd9
# 0.5294117647058824
# dot1l
# 0.6842105263157895
# cela1
# 0.7333333333333333
# esr2
# 0.47058823529411764
# melk
# 0.6111111111111112
# grk2
# 0.7058823529411765
# tgfbr1
# 0.4444444444444444
# nr3c2
# 0.7058823529411765
# lef
# 0.7222222222222222
# pak1
# 0.5882352941176471
# keap1
# 0.875
# hras
# 0.5555555555555556
# akt1
# 0.7058823529411765
# hpgds
# 0.2222222222222222
# nek2
# 0.8947368421052632
# ldha
# 0.6111111111111112
# ntrk1
# 0.5
# map3k7
# 0.7222222222222222
# ca1
# 0.375
# blandm-1
# 0.4
# fbp1
# 0.75
# ppia
# 0.7857142857142857
# adam17
# 0.6666666666666666
# adora2a
# 0.6666666666666666
# enpp2
# 0.6666666666666666
# ispu
# 0.3
# rock1
# 0.3888888888888889
# map3k5
# 0.7222222222222222
# nrp1
# 0.875
# usp7
# 0.7692307692307693
# faah
# 0.6470588235294118
# fgfr4
# 0.4666666666666667
# gyrb
# 0.3125
# ptk2
# 0.42857142857142855
# esrrg
# 0.7857142857142857
# leca
# 0.21428571428571427
# umps
# nan
# sting1
# 0.4
# igf1r
# 0.4117647058823529
# alb
# /home/benoit/anaconda3/envs/GeoMol/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3420: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /home/benoit/anaconda3/envs/GeoMol/lib/python3.7/site-packages/numpy/core/_methods.py:188: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# 0.36363636363636365
# ca12
# 0.625
# cdpk1
# 0.625
# bcl2
# 0.75
# ptpn11
# 0.6363636363636364
# parp14
# 0.5833333333333334
# rpa1
# 0.6923076923076923
# mmp8
# 0.42857142857142855
# lpxc
# 0.5333333333333333
# dck
# 0.8125
# hint1
# 0.6666666666666666
# hspa8
# 0.5
# nr1h2
# 0.8125
# ada
# 0.6666666666666666
# gart
# 0.8666666666666667
# cgas
# 0.5555555555555556
# grb2
# nan
# hprt1
# 0.0
# dxr
# nan
# cpa1
# 0.4166666666666667
# ephb4
# 0.6428571428571429
# gls
# 0.9230769230769231
# ppif
# 0.8333333333333334
# ywhaz
# nan
# ripk2
# 0.13333333333333333
# lgb
# 0.5714285714285714
# pde6d
# 0.7692307692307693
# alpha-lp
# 1.0
# eif4e
# 0.0
# rabggta
# 0.5555555555555556
# crtm
# 0.0
# grin1
# 0.6428571428571429
# fimh
# 0.7142857142857143
# stk24
# 0.14285714285714285
# pfkfb3
# 0.9285714285714286
# egln1
# 0.46153846153846156
# chka
# 0.7692307692307693
# mapkapk2
# 0.4166666666666667
# fto
# 0.42857142857142855
# lacz
# 0.0
# furin
# 0.6666666666666666
# gckr
# 1.0
# bts1
# nan
# phgdh
# 0.46153846153846156
# mapk8
# 0.1
# gstp1
# 0.2222222222222222
# shc
# 0.7692307692307693
# prep
# 0.9230769230769231
# setd7
# 0.4
# adcy10
# 0.36363636363636365
# hmgcr
# 1.0
# pde9a
# 0.8333333333333334
# tyms
# 0.5
# fkbp1a
# 0.5
# nsd3
# 0.5454545454545454
# pyrf
# nan
# ddr1
# 0.25
# na
# 0.2727272727272727
# elane
# 0.6666666666666666
# lecb
# 0.5
# ide
# 0.8181818181818182
# cd1d1
# 1.0
# hsp90b1
# 0.7272727272727273
# carm1
# 0.0
# grik3
# 0.5
# pck1
# 0.7142857142857143
# brca1
# nan
# pak4
# 0.4166666666666667
# kdm5b
# 0.4444444444444444
# klk6
# 0.7777777777777778
# wee1
# 0.6363636363636364
# hif1an
# 0.18181818181818182
# casp7
# 0.2727272727272727
# smyd2
# 0.8
# vcp
# 0.0
# blaoxa-33
# 0.6
# ehmt1
# 0.7272727272727273
# ptk2b
# 0.4444444444444444
# aroq
# 0.6
# mmp9
# 0.0
# cma1
# 0.875
# thrb
# 0.8888888888888888
# ripk1
# 0.36363636363636365
# ogt
# 1.0
# chib1
# 0.5454545454545454
# bira
# 1.0
# ptges
# 0.45454545454545453
# amy2a
# 0.0
# cdk9
# 0.4
# cert1
# 1.0
# map3k14
# 0.6363636363636364
# tnnc1
# 0.0
# male
# 0.0
# setdb1
# 0.0
# pdk2
# 0.6
# chib
# 0.5714285714285714
# hdac6
# 0.8
# plg
# 0.4
# ca13
# 0.5
# polm
# nan
# pdeb1
# 0.8
# gp
# 0.4
# kat8
# 1.0
# fabp3
# 0.375
# hck
# 0.7777777777777778
# mertk
# 0.6
# csf1r
# 0.3333333333333333
# dapk1
# 0.4
# vdra
# 0.875
# lcn2
# 0.2857142857142857
# map2k7
# 0.7
# sirt2
# 0.5
# haspin
# 0.625
# ern1
# 0.4444444444444444
# aroa
# 0.0
# parp3
# 0.6
# fscn1
# 0.8
# rpoa
# 0.6666666666666666
# dlg4
# 1.0
# avd
# 0.3333333333333333
# ctsc
# 0.8
# mgam
# 0.7777777777777778
# ca4
# 0.3333333333333333
# ehmt2
# 0.42857142857142855
# biod
# nan
# amd1
# 0.5555555555555556
# nr3c1
# 0.375
# dac
# 0.5
# ha
# 1.0
# abo
# 1.0
# st14
# 0.6666666666666666
# prkaa1
# 0.8333333333333334
# pkm
# 0.0
# arg2
# 0.4444444444444444
# clk1
# 0.4444444444444444
# murd
# 1.0
# grik2
# 0.2
# tdp1
# 0.42857142857142855
# birc5
# 0.6666666666666666
# birc2
# 0.75
# pcna
# 0.0
# pgr
# 0.4444444444444444
# map4k4
# 0.4444444444444444
# casp6
# 0.625
# spin1
# 1.0
# blm
# 0.4444444444444444
# crabp2
# 0.7142857142857143
# ispd
# 0.7777777777777778
# gsto1
# 0.7777777777777778
# nadk1
# 0.75
# prmt5
# 0.8571428571428571
# dsba
# 0.42857142857142855
# ethr
# 0.4444444444444444
# dut
# 0.5
# pvdq
# 0.5555555555555556
# pbrm1
# 0.75
# hdac4
# 0.8333333333333334
# blat-4
# 0.0
# ftl
# 0.5
# gba
# 0.25
# tbk1
# 0.875
# spop
# 1.0
# mapk7
# 0.625
# cbx7
# 0.0
# mllt3
# nan
# rbp2
# 0.0
# hdah
# 0.5
# cd38
# 1.0
# hgprt
# nan
# kit
# 0.0
# serpina3
# 0.8333333333333334
# dhfr
# 0.16666666666666666
# blat-3
# 0.0
# ca9
# 1.0
# mknk2
# 0.25
# dfra
# 0.75
# pkmyt1
# 0.2857142857142857
# pik3c3
# 0.75
# grb7
# 0.0
# blat-6
# 0.0
# blat-5
# 0.0
# mllt1
# 0.875
# adrb2
# 0.42857142857142855
# chit1
# 0.625
# app
# 0.0
# eif2ak3
# 0.75
# fdft1
# 0.25
# ep300
# 0.5
# grin2b
# 1.0
# def
# 0.3333333333333333
# ppard
# 0.2857142857142857
# apc
# 1.0
# ipmk
# 0.5714285714285714
# rps6kb1
# 0.6666666666666666
# apcs
# 0.8
# adok
# 0.14285714285714285
# sdh1
# 0.6
# khk
# 0.42857142857142855
# pla2g2a
# 0.5
# bbox1
# 0.3333333333333333
# phip
# 0.8571428571428571
# galc
# 0.0
# fola
# 0.4
# shbg
# 0.0
# birc7
# 0.42857142857142855
# hpd
# 0.8571428571428571
# f9
# 0.42857142857142855
# chrna7
# 0.14285714285714285
# pepn
# 0.4
# ptprg
# 1.0
# folb
# 0.42857142857142855
# pmt
# 0.0
# ispf
# 0.0
# hsp90ab1
# 0.16666666666666666
# cd44
# 0.5
# ret
# 0.5
# hgf
# 0.6
# mdla
# 0.2857142857142857
# kmt5a
# 1.0
# cobb
# 0.0
# ntmt1
# 1.0
# alkbh5
# 0.0
# mpo
# 0.4
# rep
# 0.5
# ggta1
# 0.0
# botb
# 0.0
# prss2
# 0.0
# rnta
# nan
# pygl
# 0.0
# pep4
# 0.4
# dyrk2
# 0.3333333333333333
# sftpd
# 0.4
# tph1
# 0.5
# sirt3
# 0.75
# ddah1
# 0.3333333333333333
# kdm4c
# 0.0
# chia
# 0.16666666666666666
# pomgnt1
# 0.3333333333333333
# leus
# nan
# smyd3
# 0.6666666666666666
# hdac2
# 0.6666666666666666
# srn
# nan
# lyz
# 0.0
# cdk1
# 0.0
# atp1a1
# 0.0
# dnph1
# nan
# aurkb-a
# 0.0
# kmt2a
# nan
# ppara
# 0.3333333333333333
# zipa
# 0.0
# apha
# 0.5
# hspa5
# 0.0
# taf1
# 0.0
# hcn2
# nan
# glpg
# 1.0
# pcsk9
# nan
# grm5
# 0.3333333333333333
# v-src
# nan
# insr
# 0.0
# rnase2
# 0.0
# hnmt
# 0.0
# fabh
# 0.3333333333333333
# mme
# 0.3333333333333333
# casp1
# 0.5
# casp8
# 0.16666666666666666
# idh1
# 0.6
# sort1
# 0.0
# pir
# 0.4
# mtap
# 0.6
# klk7
# 0.6
# glo1
# 0.0
# fabb
# 0.75
# epha4
# 0.0
# ddb1
# 0.75
# sgf29
# 0.3333333333333333
# acvr1
# 0.4
# oga
# 0.0
# aldh2
# 0.0
# pde1b
# 0.4
# casp2
# 0.75
# sos1
# 0.8
# tiam1
# nan
# eft2
# nan
# ran
# nan
# aldh1a1
# 0.4
# tek
# 0.2
# yap1
# 0.5
# plk2
# 0.8
# atic
# 0.75
# hemb
# 0.0
# tnf
# 0.75
# cd274
# 0.5
# mmp7
# 0.6
# ung
# 1.0
# ppip5k2
# nan
# adamts5
# 0.6
# tp53bp1
# 0.0
# map3k12
# 0.8
# cdk5
# 0.0
# setd2
# 0.8
# cxcr4
# 0.0
# f
# 0.2
# slc6a4
# 0.0
# ca7
# 0.4
# aox
# 0.6
# hspa1a
# 0.5
# nt5m
# nan
# serpina7
# 0.0
# chrm2
# 0.0
# cdk6
# 0.4
# pla2g10
# 0.6
# pla2g2e
# 1.0
# htr2b
# 0.8
# gria3
# 0.0
# ksi
# 0.5
# eft1
# nan
# rbbp4
# 0.0
# btn3a1
# nan
# gla
# 0.5
# rbp1
# 1.0
# sumo1
# nan
# atp4a
# 0.0
# rarg
# 0.75
# ntrk3
# 0.25
# kat2a
# 0.0
# bace2
# 0.0
# kpc-2
# 0.75
# pdha1
# nan
# capn1
# 0.5
# clk3
# 0.0
# clk2
# 0.0
# uida
# 0.5
# prors
# 0.5
# hsp90
# 0.0
# lap3
# 0.0
# topbp1
# nan
# nanb
# 0.5
# tpsb2
# 0.75
# fabz
# 0.75
# prkcq
# 0.5
# hdac7
# 0.5
# lgals8
# 0.0
# mgll
# 0.0
# mhca
# 1.0
# tlr8
# 0.0
# lgals1
# 0.0
# cya
# nan
# sirt6
# 0.0
# parp2
# 0.0
# csnk1g3
# 0.5
# acta1
# 0.3333333333333333
# dcun1d1
# 1.0
# fabi
# 0.25
# fcgrt
# 0.5
# p4ha2
# 0.0
# yoph
# 0.3333333333333333
# mapk13
# 0.75
# rbp4
# 0.0
# cts1
# 0.0
# csnk2a2
# 0.0
# parg
# 1.0
# serpine1
# 0.0
# rnf31
# 0.3333333333333333
# map4k1
# 0.0
# aadat
# nan
# akt2
# 0.0
# grk1
# 0.0
# aldoa
# nan
# tmk
# 0.0
# rpe65
# 1.0
# erap2
# 0.0
# pde7a
# 0.5
# itga2b
# 0.6666666666666666
# bptf
# 0.0
# s100b
# 0.0
# qpct
# 0.0
# nnmt
# 0.6666666666666666
# mray
# 0.0
# ptpn5
# 0.0
# galnt2
# 0.0
# grm2
# 0.5
# ompdc
# 0.0
# nr1h3
# 0.25
# folr2
# 0.25
# ulk1
# 0.5
# fgf1
# 1.0
# prdx5
# 0.25
# epas1
# 1.0
# ccra
# 0.0
# ctsd
# 0.6666666666666666
# pol
# 0.0
# ppp1cc
# nan
# ppp1ca
# 0.0
# tsg101
# nan
# mtnr1a
# 0.75
# adamts4
# 0.5
# padi4
# 0.6666666666666666
# ptk6
# 0.5
# tacr1
# 0.0
# terf2
# nan
# nr1i2
# 0.0
# pa
# 0.0
# dpp3
# 0.0
# ehd1
# nan
# fabp5
# 0.0
# ptpn4
# 0.0
# murf
# 1.0
# dcps
# 0.6666666666666666
# ald
# nan
# grm3
# 0.0
# capns1
# 0.6666666666666666
# notum
# 1.0
# cops5
# 0.6666666666666666
# sirt5
# 0.0
# pdk3
# 0.0
# phoa
# nan
# camkk2
# 0.0
# hlda
# 1.0
# ulk2
# 0.3333333333333333
# map3k20
# 0.3333333333333333
# fabp7
# 0.0
# cd22
# 0.0
# ntrk2
# 0.0
# aprt
# nan
# pyk
# 0.0
# sura
# nan
# ebna1
# 0.3333333333333333
# spsb2
# 0.0
# pkn1
# 0.0
# uck2
# 0.0
# il2
# 0.6666666666666666
# sigmar1
# 0.0
# man1b1
# 0.0
# ube2i
# 0.0
# nanh
# 0.0
# tead4
# nan
# traf6
# nan
# cbx3
# nan
# pik3r1
# 0.0
# aoc3
# 0.3333333333333333
# prkca
# 0.0
# nedd4
# 0.0
# fabp1
# 0.0
# acp1
# 0.3333333333333333
# lyn
# 0.0
# pgd
# nan
# amy2
# 0.0
# sh2d1a
# nan
# rb1
# nan
# bmp1
# 0.6666666666666666
# gsta1
# 0.3333333333333333
# hpn
# 0.0
# naalad2
# 0.0
# calm1
# 0.6666666666666666
# gstm1
# 1.0
# brd1
# 0.0
# ffar1
# 0.0
# snrnp200
# 0.0
# rac1
# nan
# kdm6b
# 0.0
# gnai1
# 0.0
# n
# 1.0
# anpep
# 0.0
# ptpn9
# nan
# cysk
# 0.3333333333333333
# chd1
# 0.0
# sod1
# 0.0
# qpctl
# 0.0
# taf3
# nan
# pdk4
# 0.0
# gak
# 0.0
# cftr
# 0.0
# brd3
# 0.0
# map3k8
# 0.0
# sphk1
# 0.3333333333333333
# smarca2
# 0.0
# lgals7b
# 1.0
# eif2ak4
# 0.6666666666666666
# cyac
# 0.0
# chrna4
# 0.0
# frq2
# 0.0
# tnni3k
# 0.3333333333333333
# fgf2
# 0.6666666666666666
# tead2
# 1.0
# hk2
# 0.6666666666666666
# lgals7
# 1.0
# cbx1
# nan
# serpinc1
# nan
# ul80
# 0.0
# neu2
# 0.0
# glp1r
# 0.0
# metg
# 0.0
# sult1a1
# 0.0
# skp1
# nan
# p2rx3
# 0.0
# eis
# 0.0
# usp14
# 1.0
# mrcb
# 0.0
# itpr1
# nan
# blauoe-1
# 0.0
# dnmbp
# nan
# gaa
# 0.0
# nagz
# 0.6666666666666666
# pbpb
# 0.3333333333333333
# plcg1
# nan
# prkaa2
# 0.0
# prfa
# 0.3333333333333333
# ptgds
# nan
# dnk
# 0.0
# gpx4
# nan
# hsd17b1
# 0.0
# hcn4
# nan
# prkci
# 0.0
# cpha
# 0.0
# malt1
# 0.6666666666666666
# irf3
# nan
# muri
# 0.0
# pla2g1b
# 0.0
# ura3
# nan
# glmu
# 0.0
# fen1
# 0.0
# rnasel
# nan
# hla-a
# nan
# ephb3
# 1.0
# pgk1
# 0.0
# htr2c
# 0.0
# mmp1
# 0.0
# folr1
# 0.0
# kmt2d
# nan
# inpp5b
# nan
# cbx8
# nan
# ogdh
# nan
# mtnn
# 0.0
# uba5
# nan
# cdc42bpb
# 0.0
# aoc1
# 0.0
# pxn
# nan
# hcrtr1
# 0.0
# acp3
# 0.0
# nt5c2
# 0.0
# nme2
# nan
# p2ry1
# 0.0
# rbbp7
# nan
# mapk9
# 0.0
# gpi
# nan
# pank3
# 0.0
# erbb4
# 1.0
# trap1
# 0.5
# prdm9
# 0.0
# mapk3
# 0.0
# mphosph8
# nan
# fpps
# nan
# tjp1
# nan
# smn1
# 0.0
# ephb1
# 1.0
# gria4
# 0.0
# hla-dqa1
# nan
# fabp6
# 0.0
# spt1
# nan
# fkbp3
# nan
# apoa1
# 0.0
# pex14
# nan
# hex
# 0.0
# pdxk
# 0.0
# tars1
# 0.0
# abl2
# 0.0
# stip1
# 0.5
# rps6ka1
# 0.0
# rorb
# 0.0
# syt1
# nan
# ros1
# 0.0
# fasn
# 0.0
# dapk3
# 0.0
# aip
# 0.0
# ctnnb1
# nan
# prmt6
# 0.0
# smn2
# 0.0
# dapa
# 0.0
# adrm1
# nan
# eno2
# nan
# l3mbtl1
# 0.0
# pgld
# 0.0
# kdm7a
# 0.0
# htra1
# 0.0
# ptpn3
# nan
# apba1
# nan
# htr2a
# 0.0
# prss3
# 0.0
# kat6b
# nan
# vcl
# nan
# nt5c
# nan
# calm
# nan
# sele
# 0.0
# fyn
# 0.0
# nudt5
# 0.0
# rev1
# nan
# itgav
# nan
# ptgs2
# 0.0
# ctsa
# 1.0
# metc
# nan
# myc
# nan
# pdf1a
# 0.0
# ermc'
# 0.0
# prkg1
# 0.0
# naga
# 0.0
# lgals4
# 0.0
# nos3
# 0.0
# prss8
# 0.0
# ces1
# 0.0
# plc
# 0.0
# plat
# 0.0
# kdm4d
# 0.5
# mapt
# nan
# mthfd2
# 0.0
# hipa
# 0.0
# nr4a1
# 0.5
# arok
# 0.0
# cdk12
# 0.0
# adamts1
# 1.0
# lrp6
# nan
# tnik
# 0.0
# ezh2
# 0.0
# luxs
# 1.0
# ppa
# 1.0
# hcrtr2
# 0.0
# rock2
# 0.0
# ogfod1
# 0.0
# ispb
# 0.0
# crk
# nan
# ager
# 0.0
# tnk2
# 0.0
# cltc
# 0.0
# nr5a1
# nan
# slc9a3r1
# 0.0
# liga
# 0.0
# chia1
# 0.0
# vav1
# nan
# cdc25b
# 0.5
# grin3a
# 0.0
# sgk1
# 0.5
# thit
# 0.0
# fba
# nan
# ntsr1
# nan
# shc1
# nan
# rheb
# 0.0
# calcrl
# 0.0
# ywhag
# nan
# cd33
# nan
# alox15
# 0.0
# ggps1
# nan
# brdt
# 0.0
# p4ha1
# nan
# smndc1
# 0.0
# cbx6
# nan
# frda
# 0.0
# magi1
# nan
# pi4kb
# 0.0
# cnot6l
# 0.0
# enpep
# 0.0
# kmt2e
# nan
# tymp
# 0.0
# ash2l
# nan
# tdrd3
# 0.0
# pepd
# 0.0
# ctsb
# 0.0
# mlkl
# 0.0
# cpb2
# 0.0
# ebp
# 0.0
# esrra
# 0.0
# gne
# 0.0
# klk5
# 0.0
# prnp
# 0.0
# bmp2k
# 0.0
# slc1a3
# 0.0
# ptger4
# 1.0
# cbx2
# nan
# acly
# 0.0
# erbb2
# 0.5
# crk2
# 0.0
# pdk1
# 0.0
# tgfbr2
# 0.0
# cad
# nan
# trmd
# 0.0
# fgfr2
# 0.0
# ctsg
# nan
# dnmt3a
# nan
# cpt2
# 1.0
# mapkapk3
# 1.0
# il17a
# nan
# prim1
# nan
# snd1
# 0.0
# klkb1
# 0.5
# pabpc1
# nan
# gabrb2
# 0.0
# ttbk1
# 0.0
# pde3b
# 0.0
# acacb
# 0.0
# kdm5c
# 0.0
# kars1
# 0.0
# ppargc1a
# 0.0
# fes
# 0.0
# agtr2
# nan
# cnr2
# 0.0
# cysltr2
# 0.0
# ubc
# nan
# cdc42
# nan
# sufu
# nan
# nme1
# nan
# bcat2
# 0.0
# amy1.1
# 0.0
# grk5
# 0.0
# eya2
# 0.0
# clpc1
# nan
# asah1
# 0.0
# fntb
# nan
# pip
# 0.0
# mazf
# nan
# si
# 0.0
# ggt1
# 0.0
# sirt1
# nan
# prmt1
# 0.0
# sumo3
# nan
# crabp1
# 0.0
# rho
# nan
# idh3a
# nan
# coaw
# nan
# ns5b
# 0.0
# rhob
# nan
# mapk11
# 0.0
# cbx4
# nan
# hly
# nan
# wee2
# 0.0
# zap70
# 0.0
# ctdsp1
# 0.0
# sult1e1
# 0.0
# mark4
# 0.0
# spm-1
# 0.0
# mettl11b
# 0.0
# plk4
# 0.0
# ksr2
# 0.0
# pten
# 0.0
# ephb2
# nan
# kdm4e
# 0.0
# psma2
# 0.0
# serpina6
# 0.0
# dvl1
# 0.0
# grip1
# 0.0
# tnfsf13b
# nan
# e2
# 0.0
# lpl
# 0.0
# prkch
# 0.0
# nadd
# 0.0
# actb
# 0.0
# casr
# 0.0
# prt
# 0.0
# shh
# nan
# ddr2
# 0.0
# ywhae
# nan
# itga5
# 0.0
# h3c13
# nan
# otc
# nan
# apobec3g
# 0.0
# cttn
# nan
# a085r
# 0.0
# nfe2l2
# nan
# srpk2
# 0.0
# sgpl1
# 0.0
# itga4
# 0.0
# flt3
# 0.0
# abcc1
# nan
# glc-1
# nan
# ptger3
# 0.0
# flt1
# 0.0
# siglec8
# nan
# ppp3ca
# nan
# kdm6a
# 0.0
# thra
# 0.0
# betvia
# 0.0
# pnkp
# nan
# naa60
# nan
# adk
# 0.0
# hisg
# 0.0
# h3c15
# nan
# lig4
# nan
# pepq
# nan
# ncs1
# 0.0
# fn1
# nan
# fadl
# 0.0
# inmt
# 0.0
# xdh
# 0.0
# plek
# nan
# ppig
# nan
# bhmt
# 0.0
# kmt5b
# 0.0
# arnt
# 0.0
# papd
# 0.0
# irs1
# nan
# kat7
# 0.0
# xdha
# 0.0
# pim2
# 0.0
# s100a10
# nan
# rela
# nan
# htt
# nan
# pfk
# nan
# mrca
# 0.0
# ccr7
# 0.0
# ube2t
# 0.0
# naaa
# 0.0
# usp15
# 0.0
# vhl
# nan
# igf1
# nan
# mmp20
# 0.0
# ccr5
# nan
# tgm2
# 0.0
# arog
# nan
# lypla1
# 0.0
# pknb
# 0.0
# entpd2
# 0.0
# parp15
# 0.0
# odc1
# 0.0
# eprs1
# 0.0
# pik3cb
# 0.0
# srpk1
# 0.0
# p2rx7
# nan
# klk4
# nan
# deoa
# 0.0
# rara
# 0.0
# rarb
# 0.0
# nr1i3
# 0.0
# bmy1
# 0.0
# pde12
# 0.0
# prkab2
# nan
# b2m
# nan
# ythdf2
# 0.0
# oard1
# nan
# cnot1
# nan
# blaper-2
# 0.0
# ptprz1
# 0.0
# eif4a1
# 0.0
# smurf1
# nan
# kasa
# 0.0
# mat2a
# 0.0
# ente
# nan
# taf1l
# 0.0
# camc
# 0.0
# lepb
# 0.0
# gmk
# nan
# kat6a
# nan
# glra3
# 0.0
# dapb
# nan
# grk6
# 0.0
# fadd32
# 0.0
# mmp11
# nan
# ngfr
# 0.0
# impa1
# nan
# tcts-154
# 0.0
# egln2
# 0.0
# hst2
# nan
# arf6
# nan
# riok2
# 0.0
# bcl2a1
# nan
# lyplal1
# 0.0
# mettl3
# 0.0
# asap1
# nan
# il5ra
# nan
# ednrb
# 0.0
# acmsd
# 0.0
# fars2
# 0.0
# iunh
# 0.0
# inppl1
# nan
# tag
# 0.0
# echs1
# nan
# csnk1a1
# 0.0
# ltc4s
# 0.0
# cd40lg
# nan
# flda
# 0.0
# dcun1d2
# nan
# mastl
# 0.0
# kpna2
# nan
# hsd17b4
# 0.0
# glna
# nan
# rfac
# nan
# blactx-m-14
# 0.0
# tcda
# nan
# lypla2
# 0.0
# nmt1
# 0.0
# kdm8
# 0.0
# prok
# nan
# vps4b
# nan
# h3c14
# nan
# pik3c2a
# nan
# aurkb
# 0.0
# chrna9
# nan
# cpa4
# 0.0
# alr
# 0.0
# dxs
# nan
# ltp1
# 0.0
# limk2
# 0.0
# cnr1
# 0.0
# map3k9
# 0.0
# mark2
# 0.0
# clpp
# nan
# zmpste24
# nan
# chd4
# nan
# mst1
# 0.0
# vegfa
# nan
# gcgr
# 0.0
# il13ra1
# 0.0
# plcd1
# nan
# mat1a
# 0.0
# yeats4
# nan
# sf3b3
# 0.0
# gzmb
# 0.0
# grol
# nan
# ppp5c
# 0.0
# ywhaq
# nan
# lss
# 0.0
# c5ar1
# 0.0
# shmt2
# 0.0
# env
# nan
# grik4
# 0.0
# f2rl3
# nan
# cd1d
# nan
# dclk1
# 0.0
# aldh1a2
# 0.0
# map4k3
# 0.0
# pmi1
# nan
# th
# 0.0
# fkbo
# 0.0
# cab39
# 0.0
# dusp3
# 0.0
# gda
# 0.0
# tnfrsf1a
# 0.0
# parp10
# 0.0
# ccr2
# 0.0
# csnk1e
# 0.0
# grin2a
# 0.0
# blab1
# 0.0
# rpsa
# 0.0
# prpf4b
# 0.0
# mfn2
# nan
# maob
# 0.0
# dyrk3
# 0.0
# oprm1
# 0.0
# fabp2
# 0.0
# tpi1
# nan
# snupn
# nan
# pane
# nan
# ece1
# nan
# iles
# 0.0
# ptpn22
# 0.0
# ppib
# nan
# glpk
# nan
# ppm1a
# nan
# dnmt1
# 0.0
# pdf
# 0.0
# lnpep
# nan
# crhr1
# 0.0
# mura
# nan
# bub1
# 0.0
# prmt3
# 0.0
# ywhab
# 0.0
# yars1
# 0.0
# taok2
# 0.0
# penp
# 0.0
# srm
# 0.0
# prkcb
# 0.0
# ccl11
# nan
# cd209
# nan
# s1pr1
# nan
# rrm1
# 0.0
# mmp16
# 0.0
# tdcf
# 0.0
# tpsab1
# 0.0
# gstm2
# 0.0
# eps15
# 0.0
# menb
# nan
# smarca4
# nan
# eif4ebp1
# nan
# colh
# 0.0
# nck1
# nan
# glb1
# 0.0
# mrda
# 0.0
# cd207
# 0.0
# ccr9
# nan
# alox5ap
# 0.0
# stk3
# 0.0
# plaa
# 0.0
# hexb
# 0.0
# prkab1
# nan
# ncf1
# nan
# smurf2
# nan
# pde4a
# 0.0
# p2ry12
# 0.0
# yeats2
# nan
# cxcl8
# nan
# nr5a2
# nan
# prkar2a
# 0.0
# gag-pro
# nan
# tf
# 0.0
# cecr2
# 0.0
# fkbp4
# nan
# mdfa
# 0.0
# ptpa
# 0.0
# lgmn
# 0.0
# oprk1
# 0.0
# fkbp2
# nan
# clk4
# 0.0
# chkb
# nan
# c3
# nan
# fbaa
# nan
# sap5
# 0.0
# grin3b
# 0.0
# epha3
# 0.0
# napepld
# 0.0
# f8
# 0.0
# folp
# 0.0
# jmjd6
# 0.0
# daca
# 0.0
# aldh3a1
# 0.0
# ntn1
# nan
# erbb3
# 0.0
# blafez-1
# 0.0
# drd4
# 0.0
# abcb1a
# 0.0
# nae1
# 0.0
# cbx5
# nan
# nudt2
# nan
# parn
# nan
# sqstm1
# 0.0
# irak1
# 0.0
# ercc1
# nan
# axl
# 0.0
# fbpc
# nan
# ca14
# 0.0
# tdp2
# 0.0
# pde8a
# 0.0
# pdxp
# nan
# nos2
# 0.0
# ak
# 0.0
# e2f2
# nan
# trm3
# 0.0
# f2r
# 0.0
# agtr1
# nan
